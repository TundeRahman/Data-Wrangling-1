# %% [markdown]
# <a href="https://colab.research.google.com/github/TundeRahman/Data-Wrangling-1/blob/main/socarata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np

from sodapy import Socrata

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.cityofnewyork.us", None)


results = client.get("869v-vr48", limit=2000)

results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
socrata_domain = "data.cityofnewyork.us"
socrata_dataset_identifier = "869v-vr4"

# %%
client = Socrata(socrata_domain, None)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**client.__dict__))
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Domain: data.cityofnewyork.us
# Session: <requests.sessions.Session object at 0x7e48c2d983e0>
# URI Prefix: https://

# %%
socrata_dataset_identifier = "869v-vr48" # Corrected dataset identifier
results = client.get(socrata_dataset_identifier)
df = pd.DataFrame.from_dict(results)
df.head()
# Out:
#   summons_number plate_id registration_state plate_type  \
# 0     1484697303  JER1863                 NY        PAS
# 1     1484697315  KEV4487                 NY        PAS
# 2     1484697625   H73NYD                 NJ        PAS
# 3     1484697674  GJC9296                 NY        PAS
# 4     1484697686   M51PUV                 NJ        PAS
#
#                 issue_date violation_code vehicle_body_type vehicle_make  \
# 0  2022-06-10T00:00:00.000             67               SDN        TOYOT
# 1  2022-06-13T00:00:00.000             51              SUBN         JEEP
# 2  2022-06-19T00:00:00.000             63               SDN         JEEP
# 3  2022-06-19T00:00:00.000             63              SUBN        LEXUS
# 4  2022-06-19T00:00:00.000             63               SDN        HYUND
#
#   issuing_agency street_code1  ... to_hours_in_effect vehicle_color  \
# 0              P        34330  ...                ALL           BLK
# ...

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.cityofnewyork.us", "VGtCgQgTmuyc1Z9M5Qhg50QKE")

results = client.get("869v-vr48", limit=2000)
results_df = pd.DataFrame.from_records(results)
